# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in /Users/saadbazaz/opt/anaconda3/lib/python3.8/site-packages (0.5.4)

# %%
import cv2
import imutils
import numpy as np
from sklearn.metrics import pairwise

# %%
# For Game Emulation
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

import time

# %%
# global variables
bg = None
prev_pos = 0

# %%
## Initialize Selenium Browser

# https://sites.google.com/a/chromium.org/chromedriver/home
# Download ChromeDriver and extract. Then enter the fullpath here.
PATH_TO_CHROME = r"/Users/saadbazaz/Documents/FAST Studies/Digital Image Processing Lab/Project/Dino-Game-Hand-Gestures/t-rex-runner-gh-pages/chromedriver"

# The link to your Dino Game's index.html
DINO_GAME_LINK = r"/Users/saadbazaz/Documents/FAST Studies/Digital Image Processing Lab/Project/Dino-Game-Hand-Gestures/t-rex-runner-gh-pages/index.html"


browser = webdriver.Chrome(PATH_TO_CHROME)
res = browser.get('file://' + DINO_GAME_LINK)

# %%
## Initialize Selenium Action Chains

actions = ActionChains(browser)

# %% [markdown]
# ## Segmentation
# Separate the foreground (hand) from the background (everything else).

# %% [markdown]
# ### Separate main background

# %%
#--------------------------------------------------
# To find the running average over the background
#--------------------------------------------------
def run_avg(image, aWeight):
    global bg
    # initialize the background
    if bg is None:
        bg = image.copy().astype("float")
        return

    # compute weighted average, accumulate it and update the background
    cv2.accumulateWeighted(image, bg, aWeight)

# %% [markdown]
# ### Separate hand from segmented background

# %%
#---------------------------------------------
# To segment the region of hand in the image
#---------------------------------------------
def segment(image, threshold=25):
    global bg
    # find the absolute difference between background and current frame
    diff = cv2.absdiff(bg.astype("uint8"), image)

    # threshold the diff image so that we get the foreground
    thresholded = cv2.threshold(diff, threshold, 255, cv2.THRESH_BINARY)[1]

    # get the contours in the thresholded image
    (cnts, _) = cv2.findContours(thresholded.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # return None, if no contours detected
    if len(cnts) == 0:
        return
    else:
        # based on contour area, get the maximum contour which is the hand
        segmented = max(cnts, key=cv2.contourArea)
        return (thresholded, segmented)

# %% [markdown]
# ### Test Segmentation

# %%
# #-----------------
# # MAIN FUNCTION
# #-----------------
# if __name__ == "__main__":
#     # initialize weight for running average
#     aWeight = 0.5

#     # get the reference to the webcam
#     camera = cv2.VideoCapture(0)

#     # region of interest (ROI) coordinates
#     top, right, bottom, left = 10, 350, 225, 590

#     # initialize num of frames
#     num_frames = 0

#     # keep looping, until interrupted
#     while(True):
#         # get the current frame
#         (grabbed, frame) = camera.read()

#         # resize the frame
#         frame = imutils.resize(frame, width=700)

#         # flip the frame so that it is not the mirror view
#         frame = cv2.flip(frame, 1)

#         # clone the frame
#         clone = frame.copy()

#         # get the height and width of the frame
#         (height, width) = frame.shape[:2]

#         # get the ROI
#         roi = frame[top:bottom, right:left]

#         # convert the roi to grayscale and blur it
#         gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
#         gray = cv2.GaussianBlur(gray, (7, 7), 0)

#         # to get the background, keep looking till a threshold is reached
#         # so that our running average model gets calibrated
#         if num_frames < 30:
#             run_avg(gray, aWeight)
#         else:
#             # segment the hand region
#             hand = segment(gray)

#             # check whether hand region is segmented
#             if hand is not None:
#                 # if yes, unpack the thresholded image and
#                 # segmented region
#                 (thresholded, segmented) = hand

#                 # draw the segmented region and display the frame
#                 cv2.drawContours(clone, [segmented + (right, top)], -1, (0, 0, 255))
#                 cv2.imshow("Thesholded", thresholded)

#         # draw the segmented hand
#         cv2.rectangle(clone, (left, top), (right, bottom), (0,255,0), 2)

#         # increment the number of frames
#         num_frames += 1

#         # display the frame with segmented hand
#         cv2.imshow("Video Feed", clone)

#         # observe the keypress by the user
#         keypress = cv2.waitKey(1) & 0xFF

#         # if the user pressed "q", then stop looping
#         if keypress == ord("q"):
#             break

# # free up memory
# camera.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ### Recognize Hands using fingers

# %%
#--------------------------------------------------------------
# To count the number of fingers in the segmented hand region
#--------------------------------------------------------------
def count(thresholded, segmented):
    # find the convex hull of the segmented hand region
    chull = cv2.convexHull(segmented)

    # find the most extreme points in the convex hull
    extreme_top    = tuple(chull[chull[:, :, 1].argmin()][0])
    extreme_bottom = tuple(chull[chull[:, :, 1].argmax()][0])
    extreme_left   = tuple(chull[chull[:, :, 0].argmin()][0])
    extreme_right  = tuple(chull[chull[:, :, 0].argmax()][0])

    # find the center of the palm
    cX = int((extreme_left[0] + extreme_right[0]) / 2)
    cY = int((extreme_top[1] + extreme_bottom[1]) / 2)

    # find the maximum euclidean distance between the center of the palm
    # and the most extreme points of the convex hull
    distance = pairwise.euclidean_distances([(cX, cY)], Y=[extreme_left, extreme_right, extreme_top, extreme_bottom])[0]
    maximum_distance = distance[distance.argmax()]

    # calculate the radius of the circle with 80% of the max euclidean distance obtained
    radius = int(0.8 * maximum_distance)

    # find the circumference of the circle
    circumference = (2 * np.pi * radius)

    # take out the circular region of interest which has 
    # the palm and the fingers
    circular_roi = np.zeros(thresholded.shape[:2], dtype="uint8")
	
    # draw the circular ROI
    cv2.circle(circular_roi, (cX, cY), radius, 255, 1)

    # take bit-wise AND between thresholded hand using the circular ROI as the mask
    # which gives the cuts obtained using mask on the thresholded hand image
    circular_roi = cv2.bitwise_and(thresholded, thresholded, mask=circular_roi)

    # compute the contours in the circular ROI
    (cnts, _) = cv2.findContours(circular_roi.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # initalize the finger count
    count = 0

    # loop through the contours found
    for c in cnts:
        # compute the bounding box of the contour
        (x, y, w, h) = cv2.boundingRect(c)

        # increment the count of fingers only if -
        # 1. The contour region is not the wrist (bottom area)
        # 2. The number of points along the contour does not exceed
        #     25% of the circumference of the circular ROI
        if ((cY + (cY * 0.25)) > (y + h)) and ((circumference * 0.25) > c.shape[0]):
            count += 1

    return count

# %% [markdown]
# ### Segment hand region

# %%
#---------------------------------------------
# To segment the region of hand in the image
#---------------------------------------------
def segment(image, threshold=25):
    global bg
    # find the absolute difference between background and current frame
    diff = cv2.absdiff(bg.astype("uint8"), image)

    # threshold the diff image so that we get the foreground
    thresholded = cv2.threshold(diff, threshold, 255, cv2.THRESH_BINARY)[1]

    # get the contours in the thresholded image
    (cnts, _) = cv2.findContours(thresholded.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # return None, if no contours detected
    if len(cnts) == 0:
        return
    else:
        # based on contour area, get the maximum contour which is the hand
        segmented = max(cnts, key=cv2.contourArea)
        return (thresholded, segmented)

# %%
# print("Type of Contour: " + str(type(segmented)))
# print("Contour shape: " + str(segmented.shape))
# print("First 5 points in contour: " + str(segmented[:5]))

# %%
# # find the convex hull of the segmented hand region
# chull = cv2.convexHull(segmented)

# print("Type of Convex hull: " + str(type(chull)))
# print("Length of Convex hull: " + str(len(chull)))
# print("Shape of Convex hull: " + str(chull.shape))

# cv2.drawContours(image, [chull], -1, (0, 255, 0), 2)
# cv2.imshow("Convex Hull", image)

# %%
if __name__ == "__main__":
    # initialize accumulated weight
    accumWeight = 0.5

    # get the reference to the webcam
    camera = cv2.VideoCapture(0)

    # region of interest (ROI) coordinates
    top, right, bottom, left = 10, 350, 225, 590

    # initialize num of frames
    num_frames = 0

    # calibration indicator
    calibrated = False

    # keep looping, until interrupted
    while(True):
        # get the current frame
        (grabbed, frame) = camera.read()

        # resize the frame
        frame = imutils.resize(frame, width=700)

        # flip the frame so that it is not the mirror view
        frame = cv2.flip(frame, 1)

        # clone the frame
        clone = frame.copy()

        # get the height and width of the frame
        (height, width) = frame.shape[:2]

        # get the ROI
        roi = frame[top:bottom, right:left]

        # convert the roi to grayscale and blur it
        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        gray = cv2.GaussianBlur(gray, (7, 7), 0)

        # to get the background, keep looking till a threshold is reached
        # so that our weighted average model gets calibrated
        if num_frames < 30:
            run_avg(gray, accumWeight)
            if num_frames == 1:
                print("[STATUS] please wait! calibrating...")
            elif num_frames == 29:
                print("[STATUS] calibration successfull...")
        else:
            # segment the hand region
            hand = segment(gray)

            # check whether hand region is segmented
            if hand is not None:
                # if yes, unpack the thresholded image and
                # segmented region
                (thresholded, segmented) = hand

#                 print("Thresholded is: ", type(thresholded))
#                 print("Segmented is: ", type(segmented))

                feature_vector = np.concatenate( (thresholded.flatten(), segmented.flatten()) )
#                 print (hand.flatten())
                
#                 print ("FV is: ", feature_vector, ", dtype is:", feature_vector.dtype, ", length is:", feature_vector.size)
    
                # draw the segmented region and display the frame
                cv2.drawContours(clone, [segmented + (right, top)], -1, (0, 0, 255))

                # count the number of fingers
                fingers = count(thresholded, segmented)

                
#         if results.right_hand_landmarks is not None:
#             pos_y = results.right_hand_landmarks.landmark[10].y

#             ## Draw threshold lines
#             y_pix = int(np.multiply(lower_thresh, image.shape[0]))
#             cv2.line(image, (0, y_pix), (image.shape[1],  y_pix), (0,255,0), thickness=2)
            
            
#             y_pix = int(np.multiply(upper_thresh, image.shape[0]))
#             cv2.line(image, (0, y_pix), (image.shape[1],  y_pix), (255,0,0), thickness=2)
    

                if fingers == 1:
                    # print ("Jump!")


                    if prev_pos == 1:
                        pass  
                    elif prev_pos == 2:
                        actions = ActionChains(browser)                    
                        actions.key_up(Keys.DOWN)
                        actions.send_keys(Keys.SPACE)
                        actions.perform() 
                    else:
                        actions = ActionChains(browser)
                        actions.send_keys(Keys.SPACE)
                        actions.perform()                 

                    prev_pos = 1

                elif fingers == 2:
                    # print ("Duck.")

                    if prev_pos == 1:
                        actions = ActionChains(browser)
                        actions.key_down(Keys.DOWN)
                        actions.perform()     
                    elif prev_pos == 2:
                        pass
                    else:
                        actions = ActionChains(browser)
                        actions.key_down(Keys.DOWN)
                        actions.perform()                     

                    prev_pos = 2


                else:
                    # print ("Keep running.")

                    if prev_pos == 2:
                        actions = ActionChains(browser)                    
                        actions.key_up(Keys.DOWN)
                        actions.perform() 

                    prev_pos = 0                   
                
                
                cv2.putText(clone, str(fingers), (70, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
                
                # show the thresholded image
                cv2.imshow("Thesholded", thresholded)

        # draw the segmented hand
        cv2.rectangle(clone, (left, top), (right, bottom), (0,255,0), 2)

        # increment the number of frames
        num_frames += 1

        # display the frame with segmented hand
        cv2.imshow("Video Feed", clone)

        # observe the keypress by the user
        keypress = cv2.waitKey(1) & 0xFF

        # if the user pressed "q", then stop looping
        if keypress == ord("q"):
            break
    
    
    # After the loop release the cap object
    vid.release()
    # Destroy all the windows
    cv2.destroyAllWindows()
# Out:
# [STATUS] please wait! calibrating...
# [STATUS] calibration successfull...
# FV is:  [  0   0   0 ... 189 107 188] , dtype is: int32 , length is: 51684
# FV is:  [  0   0   0 ... 196  58 196] , dtype is: int32 , length is: 51626
# FV is:  [  0   0   0 ... 213  48 211] , dtype is: int32 , length is: 51618
# FV is:  [  0   0   0 ... 169  32 168] , dtype is: int32 , length is: 51674
# FV is:  [  0   0   0 ... 144  37 143] , dtype is: int32 , length is: 51878
# FV is:  [  0   0   0 ... 165  41 163] , dtype is: int32 , length is: 51766
# FV is:  [  0   0   0 ... 212  48 210] , dtype is: int32 , length is: 51640
# FV is:  [  0   0   0 ... 199  57 198] , dtype is: int32 , length is: 51630
# FV is:  [  0   0   0 ... 155  31 154] , dtype is: int32 , length is: 51890
# FV is:  [ 0  0  0 ... 56 61 54] , dtype is: int32 , length is: 52238
# FV is:  [ 0  0  0 ... 23 62 22] , dtype is: int32 , length is: 52302
# FV is:  [ 0  0  0 ... 15 66 13] , dtype is: int32 , length is: 52286
# FV is:  [ 0  0  0 ... 31 79 29] , dtype is: int32 , length is: 52388
# FV is:  [  0   0   0 ... 179  46 178] , dtype is: int32 , length is: 51764
# FV is:  [  0   0   0 ... 152 104 152] , dtype is: int32 , length is: 51726
# FV is:  [ 0  0  0 ... 52 37 52] , dtype is: int32 , length is: 51798
# FV is:  [  0   0   0 ... 151 106 151] , dtype is: int32 , length is: 51782
# FV is:  [ 0  0  0 ... 42 41 41] , dtype is: int32 , length is: 51810
# FV is:  [  0   0   0 ... 150 132 150] , dtype is: int32 , length is: 51768
# FV is:  [  0   0   0 ... 152 114 151] , dtype is: int32 , length is: 51728
# FV is:  [ 0  0  0 ... 45 38 44] , dtype is: int32 , length is: 51812
# FV is:  [  0   0   0 ... 150 128 150] , dtype is: int32 , length is: 51802
# FV is:  [ 0  0  0 ... 44 36 43] , dtype is: int32 , length is: 51750
# FV is:  [  0   0   0 ... 149 131 148] , dtype is: int32 , length is: 51830
# FV is:  [  0   0   0 ... 151 133 150] , dtype is: int32 , length is: 51734
# FV is:  [ 0  0  0 ... 46 38 44] , dtype is: int32 , length is: 51816
# FV is:  [  0   0   0 ... 150 133 149] , dtype is: int32 , length is: 51824
# FV is:  [  0   0   0 ... 152 107 151] , dtype is: int32 , length is: 51782
# FV is:  [  0   0   0 ... 149 138 149] , dtype is: int32 , length is: 51814
# FV is:  [  0   0   0 ... 152 122 151] , dtype is: int32 , length is: 51664
# FV is:  [ 0  0  0 ... 44 42 42] , dtype is: int32 , length is: 51760
# FV is:  [  0   0   0 ... 148 132 147] , dtype is: int32 , length is: 51760
# FV is:  [ 0  0  0 ... 42 37 43] , dtype is: int32 , length is: 51740
# FV is:  [ 0  0  0 ... 48 36 47] , dtype is: int32 , length is: 51846
# FV is:  [  0   0   0 ... 151 132 150] , dtype is: int32 , length is: 51618
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51814
# FV is:  [ 0  0  0 ... 79 12 78] , dtype is: int32 , length is: 51696
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51672
# FV is:  [ 0  0  0 ... 47 37 48] , dtype is: int32 , length is: 51788
# FV is:  [  0   0   0 ... 151 163 150] , dtype is: int32 , length is: 51654
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51800
# FV is:  [ 0  0  0 ... 61 18 60] , dtype is: int32 , length is: 51702
# FV is:  [ 0  0  0 ... 42 41 40] , dtype is: int32 , length is: 51666
# FV is:  [ 0  0  0 ... 41 39 40] , dtype is: int32 , length is: 51778
# FV is:  [ 0  0  0 ... 61 19 60] , dtype is: int32 , length is: 51724
# FV is:  [ 0  0  0 ... 41 50 39] , dtype is: int32 , length is: 51636
# FV is:  [ 0  0  0 ... 80 21 79] , dtype is: int32 , length is: 51694
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51752
# FV is:  [  0   0   0 ... 152 133 151] , dtype is: int32 , length is: 51616
# FV is:  [ 0  0  0 ... 45 40 46] , dtype is: int32 , length is: 51814
# FV is:  [  0   0   0 ... 149 131 148] , dtype is: int32 , length is: 51748
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51728
# FV is:  [ 0  0  0 ... 53 27 54] , dtype is: int32 , length is: 51748
# FV is:  [ 0  0  0 ... 89 21 90] , dtype is: int32 , length is: 51660
# FV is:  [  0   0   0 ... 150 177 151] , dtype is: int32 , length is: 51660
# FV is:  [ 0  0  0 ... 42 41 41] , dtype is: int32 , length is: 51756
# FV is:  [ 0  0  0 ... 51 35 52] , dtype is: int32 , length is: 51798
# FV is:  [ 0  0  0 ... 86 29 85] , dtype is: int32 , length is: 51698
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51778
# FV is:  [ 0  0  0 ... 68 20 67] , dtype is: int32 , length is: 51678
# FV is:  [ 0  0  0 ... 42 37 43] , dtype is: int32 , length is: 51654
# FV is:  [ 0  0  0 ... 47 34 48] , dtype is: int32 , length is: 51796
# FV is:  [ 0  0  0 ... 85 27 83] , dtype is: int32 , length is: 51716
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51750
# FV is:  [ 0  0  0 ... 58 29 57] , dtype is: int32 , length is: 51766
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51670
# FV is:  [ 0  0  0 ... 48 33 47] , dtype is: int32 , length is: 51784
# FV is:  [ 0  0  0 ... 41 39 42] , dtype is: int32 , length is: 51776
# FV is:  [ 0  0  0 ... 56 29 55] , dtype is: int32 , length is: 51772
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51642
# FV is:  [ 0  0  0 ... 51 40 46] , dtype is: int32 , length is: 51818
# FV is:  [ 0  0  0 ... 80 18 79] , dtype is: int32 , length is: 51690
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51722
# FV is:  [ 0  0  0 ... 54 36 53] , dtype is: int32 , length is: 51780
# FV is:  [ 0  0  0 ... 93 33 92] , dtype is: int32 , length is: 51652
# FV is:  [ 0  0  0 ... 43 41 43] , dtype is: int32 , length is: 51840
# FV is:  [ 0  0  0 ... 78 18 77] , dtype is: int32 , length is: 51688
# FV is:  [ 0  0  0 ... 42 37 43] , dtype is: int32 , length is: 51686
# FV is:  [ 0  0  0 ... 50 34 49] , dtype is: int32 , length is: 51810
# FV is:  [ 0  0  0 ... 89 27 89] , dtype is: int32 , length is: 51666
# FV is:  [ 0  0  0 ... 46 42 43] , dtype is: int32 , length is: 51802
# FV is:  [ 0  0  0 ... 67 21 66] , dtype is: int32 , length is: 51698
# FV is:  [ 0  0  0 ... 44 42 42] , dtype is: int32 , length is: 51648
# FV is:  [ 0  0  0 ... 56 36 53] , dtype is: int32 , length is: 51766
# FV is:  [ 0  0  0 ... 88 28 88] , dtype is: int32 , length is: 51682
# FV is:  [ 0  0  0 ... 43 35 44] , dtype is: int32 , length is: 51744
# FV is:  [ 0  0  0 ... 60 19 59] , dtype is: int32 , length is: 51732
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51650
# FV is:  [ 0  0  0 ... 45 38 44] , dtype is: int32 , length is: 51822
# FV is:  [ 0  0  0 ... 85 25 84] , dtype is: int32 , length is: 51660
# FV is:  [ 0  0  0 ... 43 37 43] , dtype is: int32 , length is: 51740
# FV is:  [ 0  0  0 ... 54 21 54] , dtype is: int32 , length is: 51770
# FV is:  [ 0  0  0 ... 38 56 38] , dtype is: int32 , length is: 51638
# FV is:  [ 0  0  0 ... 46 38 45] , dtype is: int32 , length is: 51824
# FV is:  [ 0  0  0 ... 80 18 79] , dtype is: int32 , length is: 51730
# FV is:  [ 0  0  0 ... 42 37 43] , dtype is: int32 , length is: 51678
# FV is:  [ 0  0  0 ... 56 26 57] , dtype is: int32 , length is: 51728
# FV is:  [ 0  0  0 ... 90 29 89] , dtype is: int32 , length is: 51648
# FV is:  [ 0  0  0 ... 47 36 46] , dtype is: int32 , length is: 51860
# FV is:  [ 0  0  0 ... 79  5 77] , dtype is: int32 , length is: 51760
# FV is:  [ 0  0  0 ... 44 36 43] , dtype is: int32 , length is: 51706
# FV is:  [ 0  0  0 ... 50 36 49] , dtype is: int32 , length is: 51786
# FV is:  [ 0  0  0 ... 91 35 91] , dtype is: int32 , length is: 51652
# FV is:  [ 0  0  0 ... 43 41 44] , dtype is: int32 , length is: 51818
# FV is:  [ 0  0  0 ... 80 18 79] , dtype is: int32 , length is: 51758
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51666
# FV is:  [ 0  0  0 ... 48 37 48] , dtype is: int32 , length is: 51790
# FV is:  [ 0  0  0 ... 84 21 85] , dtype is: int32 , length is: 51698
# FV is:  [ 0  0  0 ... 37 51 36] , dtype is: int32 , length is: 51632
# FV is:  [ 0  0  0 ... 45 38 45] , dtype is: int32 , length is: 51822
# FV is:  [ 0  0  0 ... 80 21 79] , dtype is: int32 , length is: 51722
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51760
# FV is:  [ 0  0  0 ... 57 19 57] , dtype is: int32 , length is: 51704
# FV is:  [ 0  0  0 ... 42 53 41] , dtype is: int32 , length is: 51634
# FV is:  [ 0  0  0 ... 46 41 45] , dtype is: int32 , length is: 51832
# FV is:  [ 0  0  0 ... 83 28 83] , dtype is: int32 , length is: 51674
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51724
# FV is:  [ 0  0  0 ... 53 31 53] , dtype is: int32 , length is: 51786
# FV is:  [ 0  0  0 ... 92 31 91] , dtype is: int32 , length is: 51642
# FV is:  [ 0  0  0 ... 45 40 44] , dtype is: int32 , length is: 51802
# FV is:  [ 0  0  0 ... 77 13 77] , dtype is: int32 , length is: 51682
# FV is:  [ 0  0  0 ... 43 40 41] , dtype is: int32 , length is: 51730
# FV is:  [ 0  0  0 ... 55 22 54] , dtype is: int32 , length is: 51732
# FV is:  [ 0  0  0 ... 89 24 89] , dtype is: int32 , length is: 51662
# FV is:  [ 0  0  0 ... 43 40 42] , dtype is: int32 , length is: 51844
# FV is:  [ 0  0  0 ... 78 18 77] , dtype is: int32 , length is: 51674
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51688
# FV is:  [ 0  0  0 ... 52 36 51] , dtype is: int32 , length is: 51800
# FV is:  [ 0  0  0 ... 89 24 89] , dtype is: int32 , length is: 51652
# FV is:  [ 0  0  0 ... 44 35 45] , dtype is: int32 , length is: 51770
# FV is:  [ 0  0  0 ... 68 21 67] , dtype is: int32 , length is: 51782
# FV is:  [ 0  0  0 ... 36 50 36] , dtype is: int32 , length is: 51648
# FV is:  [ 0  0  0 ... 47 34 48] , dtype is: int32 , length is: 51776
# FV is:  [ 0  0  0 ... 79 22 78] , dtype is: int32 , length is: 51734
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51758
# FV is:  [ 0  0  0 ... 57 12 56] , dtype is: int32 , length is: 51752
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51640
# FV is:  [ 0  0  0 ... 47 34 47] , dtype is: int32 , length is: 51806
# FV is:  [ 0  0  0 ... 79 18 77] , dtype is: int32 , length is: 51750
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51762
# FV is:  [ 0  0  0 ... 59 23 57] , dtype is: int32 , length is: 51730
# FV is:  [ 0  0  0 ... 92 32 92] , dtype is: int32 , length is: 51634
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51800
# FV is:  [ 0  0  0 ... 78 19 78] , dtype is: int32 , length is: 51668
# FV is:  [ 0  0  0 ... 43 42 42] , dtype is: int32 , length is: 51716
# FV is:  [ 0  0  0 ... 54 30 54] , dtype is: int32 , length is: 51794
# FV is:  [ 0  0  0 ... 90 30 90] , dtype is: int32 , length is: 51660
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51824
# FV is:  [ 0  0  0 ... 79 22 78] , dtype is: int32 , length is: 51686
# FV is:  [ 0  0  0 ... 37 44 36] , dtype is: int32 , length is: 51758
# FV is:  [ 0  0  0 ... 47 34 48] , dtype is: int32 , length is: 51802
# FV is:  [ 0  0  0 ... 90 22 92] , dtype is: int32 , length is: 51668
# FV is:  [ 0  0  0 ... 45 39 43] , dtype is: int32 , length is: 51762
# FV is:  [ 0  0  0 ... 78 12 77] , dtype is: int32 , length is: 51718
# FV is:  [ 0  0  0 ... 43 42 41] , dtype is: int32 , length is: 51696
# FV is:  [ 0  0  0 ... 49 35 48] , dtype is: int32 , length is: 51764
# FV is:  [ 0  0  0 ... 83 27 82] , dtype is: int32 , length is: 51708
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51760
# FV is:  [ 0  0  0 ... 31 50 30] , dtype is: int32 , length is: 51634
# FV is:  [ 0  0  0 ... 53 37 50] , dtype is: int32 , length is: 51770
# FV is:  [ 0  0  0 ... 84 15 83] , dtype is: int32 , length is: 51680
# FV is:  [ 0  0  0 ... 43 37 43] , dtype is: int32 , length is: 51762
# FV is:  [ 0  0  0 ... 57 21 55] , dtype is: int32 , length is: 51860
# FV is:  [ 0  0  0 ... 97 33 97] , dtype is: int32 , length is: 51618
# FV is:  [ 0  0  0 ... 45 35 45] , dtype is: int32 , length is: 51828
# FV is:  [ 0  0  0 ... 79 24 78] , dtype is: int32 , length is: 51692
# FV is:  [ 0  0  0 ... 48 42 43] , dtype is: int32 , length is: 51722
# FV is:  [ 0  0  0 ... 53 30 54] , dtype is: int32 , length is: 51844
# FV is:  [ 0  0  0 ... 90 23 90] , dtype is: int32 , length is: 51644
# FV is:  [ 0  0  0 ... 68 13 67] , dtype is: int32 , length is: 51686
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51738
# FV is:  [ 0  0  0 ... 89 21 90] , dtype is: int32 , length is: 51694
# FV is:  [ 0  0  0 ... 67 17 66] , dtype is: int32 , length is: 51662
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51654
# FV is:  [ 0  0  0 ... 54 29 53] , dtype is: int32 , length is: 51754
# FV is:  [ 0  0  0 ... 89 24 89] , dtype is: int32 , length is: 51640
# FV is:  [ 0  0  0 ... 43 38 44] , dtype is: int32 , length is: 51756
# FV is:  [ 0  0  0 ... 60 13 61] , dtype is: int32 , length is: 51694
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51662
# FV is:  [ 0  0  0 ... 49 37 48] , dtype is: int32 , length is: 51836
# FV is:  [ 0  0  0 ... 79 11 77] , dtype is: int32 , length is: 51642
# FV is:  [ 0  0  0 ... 44 40 42] , dtype is: int32 , length is: 51754
# FV is:  [ 0  0  0 ... 98 33 98] , dtype is: int32 , length is: 51618
# FV is:  [ 0  0  0 ... 48 34 48] , dtype is: int32 , length is: 51858
# FV is:  [ 0  0  0 ... 80 24 78] , dtype is: int32 , length is: 51656
# FV is:  [ 0  0  0 ... 44 41 42] , dtype is: int32 , length is: 51744
# FV is:  [ 0  0  0 ... 55 22 54] , dtype is: int32 , length is: 51730
# FV is:  [ 0  0  0 ... 44 40 43] , dtype is: int32 , length is: 51628
# FV is:  [ 0  0  0 ... 45 38 44] , dtype is: int32 , length is: 51810
# FV is:  [ 0  0  0 ... 79 18 77] , dtype is: int32 , length is: 51704
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51712
# FV is:  [ 0  0  0 ... 53 31 53] , dtype is: int32 , length is: 51794
# FV is:  [ 0  0  0 ... 91 21 90] , dtype is: int32 , length is: 51702
# FV is:  [ 0  0  0 ... 45 40 44] , dtype is: int32 , length is: 51762
# FV is:  [ 0  0  0 ... 78 24 78] , dtype is: int32 , length is: 51654
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51662
# FV is:  [ 0  0  0 ... 51 34 49] , dtype is: int32 , length is: 51800
# FV is:  [ 0  0  0 ... 87 11 86] , dtype is: int32 , length is: 51638
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51744
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51664
# FV is:  [ 0  0  0 ... 46 34 47] , dtype is: int32 , length is: 51766
# FV is:  [ 0  0  0 ... 90 29 89] , dtype is: int32 , length is: 51682
# FV is:  [ 0  0  0 ... 42 35 43] , dtype is: int32 , length is: 51754
# FV is:  [ 0  0  0 ... 57 19 57] , dtype is: int32 , length is: 51744
# FV is:  [  0   0   0 ... 151 132 150] , dtype is: int32 , length is: 51802
# FV is:  [ 0  0  0 ... 46 41 45] , dtype is: int32 , length is: 51866
# FV is:  [  0   0   0 ... 150 176 150] , dtype is: int32 , length is: 51710
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51744
# FV is:  [  0   0   0 ... 149 131 149] , dtype is: int32 , length is: 51822
# FV is:  [  0   0   0 ... 151 172 150] , dtype is: int32 , length is: 51698
# FV is:  [ 0  0  0 ... 48 33 47] , dtype is: int32 , length is: 51814
# FV is:  [  0   0   0 ... 149 131 148] , dtype is: int32 , length is: 51828
# FV is:  [ 0  0  0 ... 41 41 40] , dtype is: int32 , length is: 51742
# FV is:  [ 0  0  0 ... 53 35 52] , dtype is: int32 , length is: 51742
# FV is:  [  0   0   0 ... 152 161 151] , dtype is: int32 , length is: 51646
# FV is:  [ 0  0  0 ... 46 42 45] , dtype is: int32 , length is: 51786
# FV is:  [  0   0   0 ... 149 133 148] , dtype is: int32 , length is: 51780
# FV is:  [  0   0   0 ... 152 112 151] , dtype is: int32 , length is: 51730
# FV is:  [  0   0   0 ... 149 132 148] , dtype is: int32 , length is: 51814
# FV is:  [ 0  0  0 ... 93 33 92] , dtype is: int32 , length is: 51644
# FV is:  [  0   0   0 ... 152 239 151] , dtype is: int32 , length is: 51724
# FV is:  [ 0  0  0 ... 61 16 60] , dtype is: int32 , length is: 51686
# FV is:  [  0   0   0 ... 153  78 154] , dtype is: int32 , length is: 51616
# FV is:  [  0   0   0 ... 152 177 152] , dtype is: int32 , length is: 51674
# FV is:  [  0   0   0 ... 154 239 151] , dtype is: int32 , length is: 51654
# FV is:  [  0   0   0 ... 154  71 153] , dtype is: int32 , length is: 51612
# FV is:  [  0   0   0 ...   0 136 162] , dtype is: int32 , length is: 51602
# FV is:  [  0   0   0 ... 184   5 173] , dtype is: int32 , length is: 51618
# FV is:  [  0   0   0 ... 156   2 151] , dtype is: int32 , length is: 51646
# FV is:  [  0   0   0 ... 151   1 149] , dtype is: int32 , length is: 51686
# FV is:  [  0   0   0 ... 145   2 144] , dtype is: int32 , length is: 51694
# FV is:  [  0   0   0 ... 139   2 138] , dtype is: int32 , length is: 51702
# FV is:  [  0   0   0 ... 139   4 138] , dtype is: int32 , length is: 51728
# FV is:  [  0   0   0 ... 139   6 138] , dtype is: int32 , length is: 51730
# FV is:  [  0   0   0 ... 138   1 137] , dtype is: int32 , length is: 51726
# FV is:  [  0   0   0 ... 139   3 138] , dtype is: int32 , length is: 51720
# FV is:  [  0   0   0 ... 139   2 138] , dtype is: int32 , length is: 51714
# FV is:  [  0   0   0 ... 139   3 138] , dtype is: int32 , length is: 51726
# FV is:  [  0   0   0 ... 138   1 137] , dtype is: int32 , length is: 51730
# FV is:  [  0   0   0 ... 137   1 136] , dtype is: int32 , length is: 51774
# FV is:  [  0   0   0 ... 137   3 136] , dtype is: int32 , length is: 51756
# FV is:  [  0   0   0 ... 137   4 136] , dtype is: int32 , length is: 51780
# FV is:  [  0   0   0 ... 135   1 135] , dtype is: int32 , length is: 51784
# FV is:  [  0   0   0 ... 134   3 133] , dtype is: int32 , length is: 51806
# FV is:  [  0   0   0 ... 134   8 133] , dtype is: int32 , length is: 51794
# FV is:  [  0   0   0 ... 134   3 133] , dtype is: int32 , length is: 51778
# FV is:  [  0   0   0 ... 134   8 133] , dtype is: int32 , length is: 51810
# FV is:  [  0   0   0 ... 133  43 132] , dtype is: int32 , length is: 51862
# FV is:  [  0   0   0 ... 133  43 132] , dtype is: int32 , length is: 51862
# FV is:  [  0   0   0 ... 134  42 133] , dtype is: int32 , length is: 51938
# FV is:  [  0   0   0 ... 133  42 132] , dtype is: int32 , length is: 51988
# FV is:  [  0   0   0 ... 135  50 133] , dtype is: int32 , length is: 51950
# FV is:  [  0   0   0 ... 137  52 134] , dtype is: int32 , length is: 51938
# FV is:  [  0   0   0 ... 137  51 134] , dtype is: int32 , length is: 51966
# FV is:  [  0   0   0 ... 137  50 134] , dtype is: int32 , length is: 51976
# FV is:  [  0   0   0 ... 137  46 134] , dtype is: int32 , length is: 51956
# FV is:  [  0   0   0 ... 135  41 135] , dtype is: int32 , length is: 51950
# FV is:  [  0   0   0 ... 138  35 137] , dtype is: int32 , length is: 51938
# FV is:  [  0   0   0 ... 139  46 138] , dtype is: int32 , length is: 51872
# FV is:  [  0   0   0 ... 138  41 137] , dtype is: int32 , length is: 51896
# FV is:  [  0   0   0 ... 139  11 138] , dtype is: int32 , length is: 51806
# FV is:  [  0   0   0 ... 138   1 137] , dtype is: int32 , length is: 51802
# FV is:  [  0   0   0 ... 137   4 136] , dtype is: int32 , length is: 51736
# FV is:  [  0   0   0 ... 138   6 137] , dtype is: int32 , length is: 51736
# FV is:  [  0   0   0 ... 140   9 139] , dtype is: int32 , length is: 51708
# FV is:  [  0   0   0 ... 139   3 138] , dtype is: int32 , length is: 51718
# FV is:  [  0   0   0 ... 143   2 139] , dtype is: int32 , length is: 51702
# FV is:  [  0   0   0 ... 142   1 141] , dtype is: int32 , length is: 51704
# FV is:  [  0   0   0 ... 149   1 145] , dtype is: int32 , length is: 51698
# FV is:  [  0   0   0 ... 155   8 153] , dtype is: int32 , length is: 51660
# FV is:  [  0   0   0 ... 153  56 152] , dtype is: int32 , length is: 51674
# FV is:  [  0   0   0 ... 164   5 163] , dtype is: int32 , length is: 51642
# FV is:  [  0   0   0 ... 152 208 151] , dtype is: int32 , length is: 51720
# FV is:  [  0   0   0 ... 161 113 160] , dtype is: int32 , length is: 51622
# FV is:  [  0   0   0 ... 154  83 153] , dtype is: int32 , length is: 51610
# FV is:  [  0   0   0 ... 164   3 163] , dtype is: int32 , length is: 51614
# FV is:  [  0   0   0 ... 157   5 155] , dtype is: int32 , length is: 51640
# FV is:  [  0   0   0 ... 141   2 140] , dtype is: int32 , length is: 51662
# FV is:  [  0   0   0 ... 142   2 140] , dtype is: int32 , length is: 51710
# FV is:  [  0   0   0 ... 136   5 135] , dtype is: int32 , length is: 51710
# FV is:  [  0   0   0 ... 129   1 128] , dtype is: int32 , length is: 51768
# FV is:  [  0   0   0 ... 132   7 129] , dtype is: int32 , length is: 51772
# FV is:  [  0   0   0 ... 125   1 124] , dtype is: int32 , length is: 51772
# FV is:  [  0   0   0 ... 125   2 124] , dtype is: int32 , length is: 51780
# FV is:  [  0   0   0 ... 129   7 125] , dtype is: int32 , length is: 51770
# FV is:  [  0   0   0 ... 123   1 122] , dtype is: int32 , length is: 51764
# FV is:  [  0   0   0 ... 131   1 130] , dtype is: int32 , length is: 51702
# FV is:  [  0   0   0 ... 137   5 137] , dtype is: int32 , length is: 51686
# FV is:  [  0   0   0 ... 153   2 152] , dtype is: int32 , length is: 51644
# FV is:  [  0   0   0 ... 157   2 156] , dtype is: int32 , length is: 51612
# FV is:  [  0   0   0 ... 161 138 161] , dtype is: int32 , length is: 51628
# FV is:  [  0   0   0 ... 188 128 187] , dtype is: int32 , length is: 51634
# FV is:  [  0   0   0 ... 161 131 160] , dtype is: int32 , length is: 51622
# FV is:  [ 0  0  0 ... 48 37 48] , dtype is: int32 , length is: 51792
# FV is:  [ 0  0  0 ... 77  1 76] , dtype is: int32 , length is: 51692
# FV is:  [  0   0   0 ... 160 138 160] , dtype is: int32 , length is: 51650
# FV is:  [ 0  0  0 ... 53 30 54] , dtype is: int32 , length is: 51760
# FV is:  [  0   0   0 ... 160 132 160] , dtype is: int32 , length is: 51628
# FV is:  [ 0  0  0 ... 44 42 43] , dtype is: int32 , length is: 51760
# FV is:  [  0   0   0 ... 141  61 139] , dtype is: int32 , length is: 51788
# FV is:  [ 0  0  0 ... 30 54 29] , dtype is: int32 , length is: 51640
# FV is:  [ 0  0  0 ... 53 28 53] , dtype is: int32 , length is: 51780
# FV is:  [ 0  0  0 ... 76  5 76] , dtype is: int32 , length is: 51770
# FV is:  [  0   0   0 ... 160 138 160] , dtype is: int32 , length is: 51640
# FV is:  [ 0  0  0 ... 53 31 53] , dtype is: int32 , length is: 51796
# FV is:  [  0   0   0 ... 160 138 159] , dtype is: int32 , length is: 51636
# FV is:  [ 0  0  0 ... 46 41 45] , dtype is: int32 , length is: 51768
# FV is:  [  0   0   0 ... 140  61 139] , dtype is: int32 , length is: 51798
# FV is:  [  0   0   0 ... 160 138 159] , dtype is: int32 , length is: 51636
# FV is:  [ 0  0  0 ... 48 36 47] , dtype is: int32 , length is: 51786
# FV is:  [ 0  0  0 ... 43 41 42] , dtype is: int32 , length is: 51656
# FV is:  [ 0  0  0 ... 56 21 55] , dtype is: int32 , length is: 51736
# FV is:  [  0   0   0 ... 160 138 160] , dtype is: int32 , length is: 51626
# FV is:  [  0   0   0 ... 143 106 143] , dtype is: int32 , length is: 51696
# FV is:  [  0   0   0 ... 160 124 159] , dtype is: int32 , length is: 51658
# FV is:  [ 0  0  0 ... 50 34 49] , dtype is: int32 , length is: 51732
# FV is:  [  0   0   0 ... 140  60 139] , dtype is: int32 , length is: 51846
# FV is:  [  0   0   0 ... 161 102 160] , dtype is: int32 , length is: 51624
# FV is:  [  0   0   0 ...  59 185  58] , dtype is: int32 , length is: 51832
# FV is:  [  0   0   0 ... 160 129 160] , dtype is: int32 , length is: 51652
# FV is:  [ 0  0  0 ... 44 40 43] , dtype is: int32 , length is: 51744
# FV is:  [  0   0   0 ... 139  54 138] , dtype is: int32 , length is: 51740
# FV is:  [  0   0   0 ... 160  93 161] , dtype is: int32 , length is: 51622
# FV is:  [ 0  0  0 ... 48 36 47] , dtype is: int32 , length is: 51764
# FV is:  [ 0  0  0 ... 76 15 75] , dtype is: int32 , length is: 51676
# FV is:  [  0   0   0 ... 161 102 160] , dtype is: int32 , length is: 51644
# FV is:  [ 0  0  0 ... 55 21 54] , dtype is: int32 , length is: 51758
# FV is:  [  0   0   0 ... 160 131 159] , dtype is: int32 , length is: 51658
# FV is:  [ 0  0  0 ... 46 34 46] , dtype is: int32 , length is: 51738
# FV is:  [  0   0   0 ... 142  74 140] , dtype is: int32 , length is: 51802
# FV is:  [  0   0   0 ... 161 100 160] , dtype is: int32 , length is: 51640
# FV is:  [  0   0   0 ...  52 180  51] , dtype is: int32 , length is: 51848
# FV is:  [ 0  0  0 ... 76 16 76] , dtype is: int32 , length is: 51756
# FV is:  [  0   0   0 ... 161  93 161] , dtype is: int32 , length is: 51648
# FV is:  [ 0  0  0 ... 54 33 53] , dtype is: int32 , length is: 51728
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1517e1dc362d> in <module>
#      18     while(True):
#      19         # get the current frame
# ---> 20         (grabbed, frame) = camera.read()
#      21
#      22         # resize the frame
#
# KeyboardInterrupt:

# %%
main__test_segmentation()
